# %% [markdown]
# <a href="https://colab.research.google.com/github/charliashby/programming/blob/main/Ashby_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q2
import numpy as np
import matplotlib.pyplot as plt

#plot 1
x = np.linspace(0,1,50)
y = np.log(x)
z = np.exp(x)
plt.scatter(x,y, label ='Natural Log')
plt.scatter(x,z, label='Exponential')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc='lower right')
plt.title('Natural Log and Exponential Functions')
plt.show()

#plot 2
x = np.linspace(-6.5,6.5,100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y, label ='SINE')
plt.plot(x,z, label='COSINE')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc='lower left')
plt.title('SINE AND COSINE')
plt.show()
# Out:
# <ipython-input-6-0f4d324387cd>:6: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
